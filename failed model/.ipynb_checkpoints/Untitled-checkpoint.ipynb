# %%
from __future__ import division, print_function, absolute_import
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import json
import time
import numpy as np
import collections

import tensorflow as tf



import numpy as np
import os

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
import time

import gc
import matplotlib as plt
# Out:
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
class user(object):
    """docstring for User"""

    def __init__(self, userid):
        self.userid = userid

        self.polls = {}  # Key is pollId value is [interaction, index]

    def get_engagement_array(self, length):
        arr = np.zeros(length)
        for i in self.polls.keys():

            interaction = self.polls[i][0]

            idx = self.polls[i][1]
            arr[idx] = interaction
        return arr


    def add_interaction(self, pollid, interaction, pollidx):
        if pollid in self.polls.keys():

            if self.polls[pollid][0]>=0 and interaction>=0:
                self.polls[pollid][0] += interaction

            if self.polls[pollid][0]>=0 and interaction<0:
                self.polls[pollid][0] = self.polls[pollid][0]

            if self.polls[pollid][0] < 0 and interaction >= 0:
                self.polls[pollid][0] = interaction

            if self.polls[pollid][0] < 0 and interaction < 0:
                self.polls[pollid][0] = interaction
        else:
            self.polls[pollid] = [interaction, pollidx]

    def num_interactions(self):
        return len(self.polls)

# %%
class poll(object):
    """docstring for Poll"""

    def __init__(self, userid, pollid, title, this, that, boost=0):
        self.pollid = pollid
        self.userid = userid
        self.title = title
        self.this = this
        self.that = that
        self.boost = boost

    def get_text(self):
        return self.title + ' ' + self.this + '' + self.that

# %%
class data_preprocessing(object):

    def __init__(self, json_location= '/afs/inf.ed.ac.uk/user/s16/s1688201/Desktop/my_honours_project/failed model/this_that.json'):
        self.json_location = json_location
        self.polls = []
        self.users = collections.OrderedDict()
        self.data = []
        self.train = []
        self.test = []
        self.validation = []
        self.train_proportion = 0.70
        self.validation_proportion = 0.15


    def read_json(self):
        with open(self.json_location, 'r') as file:
            content = file.read()
        self.data = json.loads(content)

    def put_users_into_user_list(self):
        keys = self.data['users'].keys()
        for i in set(keys):
            self.users[i] = user(i)

    def put_polls_into_poll_list_and_add_user_interaction(self):
        for i in self.data['polls']:

            for j in self.data['polls'][i]:

                title = self.data['polls'][i][j]['question']
                this = self.data['polls'][i][j]['this']
                that = self.data['polls'][i][j]['that']

                p = poll(self.users[i].userid, j, title, this, that)
                self.polls.append(p)

                self.users[i].add_interaction(j, 5, self.polls.index(p))

    def check_which_user_skip_or_vote_on_the_poll(self):
        for i in self.data['votes'].keys():  # I = pollid
            if next((x for x in self.polls if x.pollid == i), None) == None:
                continue
            pollidx = self.polls.index(next((x for x in self.polls if x.pollid == i), None))
            for j in self.data['votes'][i].keys():  # J is userid
                if j not in self.users.keys():
                    self.users[j] = user(j)
                # this is where the user skips the poll
                if j in self.users.keys() and u'skip' in self.data['votes'][i][j].keys():
                    self.users[j].add_interaction(i, -1, pollidx)
                # this is where the user votes on the poll
                if j in self.users.keys() and u'this0that1removed2' in self.data['votes'][i][j].keys() and \
                        self.data['votes'][i][j][u'this0that1removed2'] in [0, 1]:
                    self.users[j].add_interaction(i, 2, pollidx)

    def check_which_user_comment_on_the_poll(self):
        for i in self.data['commentsPath'].keys():  # i = userID
            for j in self.data['commentsPath'][i].keys():  # j is pollId
                if next((x for x in self.polls if x.pollid == j), None) == None:
                    continue
                pollidx = self.polls.index(next((x for x in self.polls if x.pollid == j), None))
                # this is where the user comment on the poll
                self.users[i].add_interaction(j, 3, pollidx)

    def check_which_user_track_on_the_poll(self):
        for i in self.data['tracking'].keys():  # i = userID
            for j in self.data['tracking'][i].keys():  # j is unknown
                for k in self.data['tracking'][i][j].keys():
                    if next((x for x in self.polls if x.pollid == k), None) == None:
                        continue
                    pollidx = self.polls.index(next((x for x in self.polls if x.pollid == k), None))
                    if i not in self.users.keys():
                        self.users[i] = user(i)
                        # this is where the user track on the poll
                    self.users[i].add_interaction(k, 4, pollidx)

    def set_initial_training_and_test_data(self):
        # indices = np.random.choice(range(len(self.users)), int(len(self.users)*self.train_proportion), replace=False)

        training_amount = int(len(self.users) * self.train_proportion)
        validation_amount = int(len(self.users) * self.validation_proportion)

        training_indices = np.arange(0, training_amount)
        validation_indices = np.arange(training_amount, training_amount + validation_amount)

        total_polls = len(self.polls)
        for idx, i in enumerate(self.users.keys()):
            if self.users[i].num_interactions() > 40:
                poll_array = self.users[i].get_engagement_array(total_polls)

                if idx in training_indices:
                    self.train.append(poll_array)
                if idx in validation_indices:
                    self.validation.append(poll_array)
                else:
                    self.test.append(poll_array)


        self.train = np.asarray(self.train)
        self.test = np.asarray(self.test)
        self.validation = np.asarray(self.validation)

    def parse(self):

        self.read_json()

        self.put_users_into_user_list()

        self.put_polls_into_poll_list_and_add_user_interaction()

        self.check_which_user_skip_or_vote_on_the_poll()

        self.check_which_user_comment_on_the_poll()

        self.check_which_user_track_on_the_poll()

        self.set_initial_training_and_test_data()

# %%
'''
Step 1:
Pick up an Embedding Vector from User Embedding Matrix for a particular user 
and an Embedding Vector from Poll Embedding Matrix for a particular Poll.

Step 2 : 
Concatenate both of the vector. 
Do the same for all the movies and Users, that we want.
It will lead to a Embedding matrix where each row is made up of concatenation of Polls and User Embedding vectors.
Number of rows will be the same as Number of Users and Polls combination. 
And the column is decided by the number of factors. 
Same as Embedding dimensionality, that we discussed before. 
So the dimensions that we have now is ( # ( Users + Polls ) combination , #Factors )
'''



'''
Step 3 :
Feed it to a 1st Linear Layer where the dimension of the Linear Layer is (#Factors,10). The output will be (#(Users+Movies)combination,10).

Step 4:
Pass it through a Second Linear Layer with ReLU activation having a dimension of (10,1). The output will be (#(Users+Movies)combination,1).
'''


'''
Step 5:
This is the output that we wanted.
Earlier what we did is for each User and Movie, we did a cross product of their Embeddings which gave us a single number i.e Predicted Rating. 
Here we are using Neural Network to get that single number i.e Predicted Rating.

Step 6:
We will then try to minimize the Loss between Predicted Rating and Actual Rating, and in turn will update the model parameters (Embedding values). 
In this way we can make our predictions more accurate.
'''
class neural_network(object):# 155 27 128 101 74
    def __init__(self,num_epochs=100, display_step=100, learning_rate=0.1, batch_size=100,
                 denoising=False, new_poll_weight=0.002,masking=0, num_layers=3, num_hidden_1=10,
                 num_hidden_2=81,num_hidden_3=27,num_hidden_4=9,num_hidden_5=3,continue_from_saved=False, time_decay=1):

        self.X = tf.placeholder("float",[None,None])
        self.Y = tf.placeholder("float", [None, None])
        self.num_hidden_1 = num_hidden_1
        self.data_provider =data_preprocessing()
        self.data_provider.parse()
        # Interactions are fed as binary but using decimal helps with adding 2 interactions together


        self.num_epochs = num_epochs # initial training eppchs given training data

        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.denoising = denoising # whether to add noise to the input vectors - might help with accidental interactions
        self.new_poll_weight = new_poll_weight # How much weight new polls are given in the output layer (gives new polls some initial traction)
        self.masking = masking # TODO: Add masking to data to make synthetic users with less interactions and see if it helps
        self.num_layers = num_layers



        self.test_users = []
        self.time_decay = time_decay

        self.saver = None
        self.compressed_train = []
        self.compressed_test = []

        self.factor = int(10)
        self.num_hidden_1 = 10
        self.num_hidden_2 = 1

        self.training_data = self.data_provider.train
        self.testing_data = self.data_provider.test
        validation_data = self.data_provider.validation

        (num_of_users, num_of_polls) = np.shape(self.training_data)
        self.num_epochs = 10000

        self.training_data_x = np.random.normal(size=((num_of_users * num_of_polls), self.factor * 2))
        training_data_y = np.asarray(self.training_data)
        self.training_data_y = np.reshape(training_data_y, (-1, 1))

        (num_of_validation_users, num_of_validation_polls) = np.shape(validation_data)
        self.validation_data_x = np.random.normal(size=((num_of_validation_users * num_of_validation_polls), self.factor * 2))
        validation_data_y = np.asarray(validation_data)
        self.validation_data_y = np.reshape(validation_data_y, (1, -1))

        self.weights = {
            'layer_1': tf.Variable(tf.random.normal([self.factor*2, self.num_hidden_1])),
            'layer_2': tf.Variable(tf.random.normal([self.num_hidden_1, self.num_hidden_2])),
        }

        self.bias = {
            'bias_1': tf.Variable(tf.random.normal([self.num_hidden_1])),
            'bias_2': tf.Variable(tf.random.normal([self.num_hidden_2])),
        }


        self.encoder_op = self.forward(self.X)

        self.setup_graph()

        self.train_and_predict()

    def forward(self, x):
        layer_1 = tf.nn.relu(tf.add(tf.matmul(x, self.weights['layer_1']), self.bias['bias_1']))
        layer_2 = tf.nn.relu(tf.add(tf.matmul(layer_1, self.weights['layer_2']), self.bias['bias_2']))
        return layer_2

    def setup_graph(self):
        tf.global_variables_initializer()
        # Prediction
        self.y_pred = self.encoder_op

        self.y_true = self.Y
        self.loss = self._loss()
        self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss)

        self.init = tf.global_variables_initializer()
        self.saver = tf.train.Saver()

    def _loss(self):
        return tf.reduce_mean(tf.pow(self.y_true - self.y_pred, 2))

    def train_and_predict(self,save=True):
        gc.collect()

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())

            train_loss = []
            validation_loss = []

            for i in range(0, self.num_epochs):
                np.random.seed(0)
                batch_x = self.training_data_x[np.random.choice(self.training_data_x.shape[0], self.batch_size, replace=True), :]
                np.random.seed(0)


                batch_y = self.training_data_y[np.random.choice(self.training_data_x.shape[0], self.batch_size, replace=True), :]

                _, l_train = sess.run([self.optimizer, self.loss], feed_dict={self.X: batch_x, self.Y: batch_y})
                train_loss.append(l_train)

                l_validation = sess.run(self.loss, feed_dict={self.X: self.validation_data_x, self.Y: self.validation_data_y})
                validation_loss.append(l_validation)

                print('num of epoch is %f and the training error is %f and validation error is %f'%(i,l_train,l_validation))


            xs = np.arange(1,self.num_epochs+1,1)
            ys = train_loss
            fig, ax = plt.subplots(figsize=(12, 8))
            ax.plot(xs, ys,color = 'b')
            xs = np.arange(1, self.num_epochs+1, 1)
            ys = validation_loss
            plt.plot(xs, ys,color = 'r')
            plt.show()

            print('autoencoder finished')
        sess.close()

a  = neural_network()
# Out:
# WARNING:tensorflow:From /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /afs/inf.ed.ac.uk/user/s16/s1688201/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# num of epoch is 0.000000 and the training error is 16.267906 and validation error is 3.331343
# num of epoch is 1.000000 and the training error is 2.153582 and validation error is 3.178921
# num of epoch is 2.000000 and the training error is 2.011136 and validation error is 3.093671
# num of epoch is 3.000000 and the training error is 1.938961 and validation error is 3.041522
# num of epoch is 4.000000 and the training error is 1.899294 and validation error is 3.006757
# num of epoch is 5.000000 and the training error is 1.876659 and validation error is 2.983939
# num of epoch is 6.000000 and the training error is 1.863574 and validation error is 2.969327
# num of epoch is 7.000000 and the training error is 1.855768 and validation error is 2.960318
# num of epoch is 8.000000 and the training error is 1.850888 and validation error is 2.955095
# num of epoch is 9.000000 and the training error is 1.847673 and validation error is 2.952363
# num of epoch is 10.000000 and the training error is 1.845450 and validation error is 2.950815
# num of epoch is 11.000000 and the training error is 1.843828 and validation error is 2.949712
# num of epoch is 12.000000 and the training error is 1.842638 and validation error is 2.948967
# num of epoch is 13.000000 and the training error is 1.841781 and validation error is 2.948509
# num of epoch is 14.000000 and the training error is 1.841178 and validation error is 2.948279
# num of epoch is 15.000000 and the training error is 1.840762 and validation error is 2.948214
# num of epoch is 16.000000 and the training error is 1.840481 and validation error is 2.948272
# num of epoch is 17.000000 and the training error is 1.840297 and validation error is 2.948414
# num of epoch is 18.000000 and the training error is 1.840179 and validation error is 2.948609
# num of epoch is 19.000000 and the training error is 1.840105 and validation error is 2.948831
# num of epoch is 20.000000 and the training error is 1.840061 and validation error is 2.949060
# num of epoch is 21.000000 and the training error is 1.840034 and validation error is 2.949285
# num of epoch is 22.000000 and the training error is 1.840019 and validation error is 2.949495
# num of epoch is 23.000000 and the training error is 1.840010 and validation error is 2.949683
# num of epoch is 24.000000 and the training error is 1.840005 and validation error is 2.949847
# num of epoch is 25.000000 and the training error is 1.840002 and validation error is 2.949986
# num of epoch is 26.000000 and the training error is 1.840001 and validation error is 2.950099
# num of epoch is 27.000000 and the training error is 1.840001 and validation error is 2.950191
# num of epoch is 28.000000 and the training error is 1.840000 and validation error is 2.950259
# num of epoch is 29.000000 and the training error is 1.840000 and validation error is 2.950305
# num of epoch is 30.000000 and the training error is 1.840000 and validation error is 2.950336
# num of epoch is 31.000000 and the training error is 1.840000 and validation error is 2.950356
# num of epoch is 32.000000 and the training error is 1.840000 and validation error is 2.950369
# num of epoch is 33.000000 and the training error is 1.840000 and validation error is 2.950377
# num of epoch is 34.000000 and the training error is 1.840000 and validation error is 2.950382
# num of epoch is 35.000000 and the training error is 1.840000 and validation error is 2.950385
# num of epoch is 36.000000 and the training error is 1.840000 and validation error is 2.950387
# num of epoch is 37.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 38.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 39.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 40.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 41.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 42.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 43.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 44.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 45.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 46.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 47.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 48.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 49.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 50.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 51.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 52.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 53.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 54.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 55.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 56.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 57.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 58.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 59.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 60.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 61.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 62.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 63.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 64.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 65.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 66.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 67.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 68.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 69.000000 and the training error is 1.840000 and validation error is 2.950388
# num of epoch is 70.000000 and the training error is 1.840000 and validation error is 2.950390
# num of epoch is 71.000000 and the training error is 1.840000 and validation error is 2.950383
# num of epoch is 72.000000 and the training error is 1.840000 and validation error is 2.950419
# num of epoch is 73.000000 and the training error is 1.840000 and validation error is 2.950204
# num of epoch is 74.000000 and the training error is 1.840000 and validation error is 2.951581
# num of epoch is 75.000000 and the training error is 1.840002 and validation error is 2.942124
# num of epoch is 76.000000 and the training error is 1.840108 and validation error is 3.013143
# num of epoch is 77.000000 and the training error is 1.846009 and validation error is 2.598898
# num of epoch is 78.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 79.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 80.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 81.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 82.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 83.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 84.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 85.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 86.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 87.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 88.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 89.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 90.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 91.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 92.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 93.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 94.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 95.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 96.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 97.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 98.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 99.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 100.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 101.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 102.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 103.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 104.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 105.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 106.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 107.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 108.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 109.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 110.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 111.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 112.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 113.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 114.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 115.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 116.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 117.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 118.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 119.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 120.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 121.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 122.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 123.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 124.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 125.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 126.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 127.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 128.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 129.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 130.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 131.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 132.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 133.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 134.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 135.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 136.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 137.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 138.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 139.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 140.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 141.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 142.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 143.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 144.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 145.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 146.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 147.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 148.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 149.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 150.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 151.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 152.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 153.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 154.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 155.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 156.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 157.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 158.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 159.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 160.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 161.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 162.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 163.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 164.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 165.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 166.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 167.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 168.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 169.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 170.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 171.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 172.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 173.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 174.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 175.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 176.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 177.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 178.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 179.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 180.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 181.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 182.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 183.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 184.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 185.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 186.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 187.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 188.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 189.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 190.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 191.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 192.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 193.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 194.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 195.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 196.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 197.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 198.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 199.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 200.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 201.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 202.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 203.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 204.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 205.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 206.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 207.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 208.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 209.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 210.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 211.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 212.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 213.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 214.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 215.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 216.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 217.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 218.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 219.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 220.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 221.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 222.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 223.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 224.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 225.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 226.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 227.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 228.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 229.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 230.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 231.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 232.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 233.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 234.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 235.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 236.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 237.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 238.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 239.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 240.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 241.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 242.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 243.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 244.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 245.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 246.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 247.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 248.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 249.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 250.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 251.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 252.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 253.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 254.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 255.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 256.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 257.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 258.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 259.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 260.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 261.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 262.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 263.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 264.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 265.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 266.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 267.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 268.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 269.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 270.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 271.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 272.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 273.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 274.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 275.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 276.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 277.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 278.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 279.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 280.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 281.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 282.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 283.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 284.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 285.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 286.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 287.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 288.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 289.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 290.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 291.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 292.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 293.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 294.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 295.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 296.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 297.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 298.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 299.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 300.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 301.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 302.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 303.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 304.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 305.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 306.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 307.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 308.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 309.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 310.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 311.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 312.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 313.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 314.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 315.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 316.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 317.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 318.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 319.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 320.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 321.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 322.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 323.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 324.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 325.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 326.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 327.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 328.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 329.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 330.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 331.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 332.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 333.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 334.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 335.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 336.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 337.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 338.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 339.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 340.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 341.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 342.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 343.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 344.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 345.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 346.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 347.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 348.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 349.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 350.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 351.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 352.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 353.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 354.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 355.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 356.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 357.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 358.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 359.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 360.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 361.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 362.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 363.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 364.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 365.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 366.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 367.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 368.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 369.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 370.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 371.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 372.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 373.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 374.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 375.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 376.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 377.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 378.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 379.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 380.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 381.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 382.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 383.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 384.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 385.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 386.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 387.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 388.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 389.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 390.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 391.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 392.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 393.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 394.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 395.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 396.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 397.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 398.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 399.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 400.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 401.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 402.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 403.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 404.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 405.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 406.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 407.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 408.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 409.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 410.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 411.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 412.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 413.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 414.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 415.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 416.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 417.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 418.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 419.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 420.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 421.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 422.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 423.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 424.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 425.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 426.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 427.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 428.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 429.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 430.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 431.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 432.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 433.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 434.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 435.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 436.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 437.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 438.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 439.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 440.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 441.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 442.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 443.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 444.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 445.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 446.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 447.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 448.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 449.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 450.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 451.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 452.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 453.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 454.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 455.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 456.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 457.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 458.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 459.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 460.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 461.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 462.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 463.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 464.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 465.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 466.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 467.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 468.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 469.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 470.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 471.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 472.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 473.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 474.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 475.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 476.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 477.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 478.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 479.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 480.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 481.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 482.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 483.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 484.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 485.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 486.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 487.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 488.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 489.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 490.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 491.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 492.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 493.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 494.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 495.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 496.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 497.000000 and the training error is 1.920000 and validation error is 2.598898
# ...
# num of epoch is 1609.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1610.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1611.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1612.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1613.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1614.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1615.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1616.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1617.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1618.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1619.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1620.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1621.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1622.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1623.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1624.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1625.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1626.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1627.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1628.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1629.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1630.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1631.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1632.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1633.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1634.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1635.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1636.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1637.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1638.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1639.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1640.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1641.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1642.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1643.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1644.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1645.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1646.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1647.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1648.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1649.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1650.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1651.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1652.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1653.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1654.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1655.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1656.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1657.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1658.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1659.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1660.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1661.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1662.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1663.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1664.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1665.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1666.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1667.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1668.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1669.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1670.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1671.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1672.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1673.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1674.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1675.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1676.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1677.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1678.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1679.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1680.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1681.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1682.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1683.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1684.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1685.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1686.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1687.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1688.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1689.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1690.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1691.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1692.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1693.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1694.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1695.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1696.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1697.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1698.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1699.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1700.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1701.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1702.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1703.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1704.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1705.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1706.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1707.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1708.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1709.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1710.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1711.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1712.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1713.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1714.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1715.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1716.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1717.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1718.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1719.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1720.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1721.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1722.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1723.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1724.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1725.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1726.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1727.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1728.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1729.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1730.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1731.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1732.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1733.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1734.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1735.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1736.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1737.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1738.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1739.000000 and the training error is 1.920000 and validation error is 2.598898
# num of epoch is 1740.000000 and the training error is 1.920000 and validation error is 2.598898
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-234e6099f8d9> in <module>
#     161         sess.close()
#     162
# --> 163 a  = neural_network()
#
# <ipython-input-11-234e6099f8d9> in __init__(self, num_epochs, display_step, learning_rate, batch_size, denoising, new_poll_weight, masking, num_layers, num_hidden_1, num_hidden_2, num_hidden_3, num_hidden_4, num_hidden_5, continue_from_saved, time_decay)
#     101         self.setup_graph()
#     102
# --> 103         self.train_and_predict()
#     104
#     105     def forward(self, x):
#
# <ipython-input-11-234e6099f8d9> in train_and_predict(self, save)
#     143                 train_loss.append(l_train)
#     144
# --> 145                 l_validation = sess.run(self.loss, feed_dict={self.X: self.validation_data_x, self.Y: self.validation_data_y})
#     146                 validation_loss.append(l_validation)
#     147
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
